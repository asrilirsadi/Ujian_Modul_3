# %% [markdown]
# # Telecom Customer Churn

# %% [markdown]
# For this module examination, I would use data from Kaggle regarding Customer Churn Rate.

# %% [markdown]
# Customer attrition, also known as customer churn, customer turnover, or customer defection, is the loss of clients or customers.

# %% [markdown]
# The data set includes information about:
#
# - Customers who left within the last month – the column is called Churn
# - Services that each customer has signed up for – phone, multiple lines, internet, online security, online backup, device protection, tech support, and streaming TV and movies
# - Customer account information – how long they’ve been a customer, contract, payment method, paperless billing, monthly charges, and total charges
# - Demographic info about customers – gender, age range, and if they have partners and dependents

# %% [markdown]
# <b> Coloumns Descriptions  </b>
# - customerID = Customer ID
# - gender = Whether the customer is a male or a female
# - SeniorCitizen = Whether the customer is a senior citizen or not (1, 0)
# - Partner = Whether the customer has a partner or not (Yes, No)
# - Dependents = Whether the customer has dependents or not (Yes, No)
# - tenure = Number of months the customer has stayed with the company
# - PhoneService = Whether the customer has a phone service or not (Yes, No)
# - MultipleLines = Whether the customer has multiple lines or not (Yes, No, No phone service)
# - InternetService = Customer’s internet service provider (DSL, Fiber optic, No)
# - OnlineSecurity = Whether the customer has online security or not (Yes, No, No internet service)
# - OnlineBackup = Whether the customer has online backup or not (Yes, No, No internet service)
# - DeviceProtection = Whether the customer has device protection or not (Yes, No, No internet service)
# - TechSupport = Whether the customer has tech support or not (Yes, No, No internet service)
# - StreamingTV = Whether the customer has streaming TV or not (Yes, No, No internet service)
# - StreamingMovies = Whether the customer has streaming movies or not (Yes, No, No internet service)
# - Contract = The contract term of the customer (Month-to-month, One year, Two year)
# - PaperlessBilling = Whether the customer has paperless billing or not (Yes, No)
# - PaymentMethod = The customer’s payment method (Electronic check, Mailed check, Bank transfer (automatic), Credit card (automatic))
# - MonthlyCharges = The amount charged to the customer monthly
# - TotalCharges = The total amount charged to the customer
# - Churn = Whether the customer churned or not (Yes or No)

# %% [markdown]
# In this exam, the maximum point is 100 with the criterion is shown below:
# - The Coding Part would yield the maximum point of 30
# - 5 Question with score of:
#     - Q1 : 5 Point
#     - Q2 : 5 Point
#     - Q3 : 10 Point
#     - Q4 : 5 Point
#     - Q5 : 45 Point

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('Churn_ujian.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.describe(exclude='number').T
# Out:
#                  count unique               top  freq
# customerID        7043   7043        0402-OAMEN     1
# gender            7043      2              Male  3555
# Partner           7043      2                No  3641
# Dependents        7043      2                No  4933
# PhoneService      7043      2               Yes  6361
# MultipleLines     7043      3                No  3390
# InternetService   7043      3       Fiber optic  3096
# OnlineSecurity    7043      3                No  3498
# OnlineBackup      7043      3                No  3088
# DeviceProtection  7043      3                No  3095
# TechSupport       7043      3                No  3473
# StreamingTV       7043      3                No  2810
# StreamingMovies   7043      3                No  2785
# Contract          7043      3    Month-to-month  3875
# PaperlessBilling  7043      2               Yes  4171
# PaymentMethod     7043      4  Electronic check  2365
# ...

# %%
dfDesc = []
for i in df.columns:
    dfDesc.append([i, 
                      df[i].dtypes, 
                      df[i].isna().sum(), 
                      round((((df[i].isna().sum())/(len(df)))*100),2), 
                      df[i].nunique(),
                      df[i].drop_duplicates().sample(2).values])
    
pd.DataFrame(dfDesc, columns = ['dataFeatures', 'dataType', 'null', 'nullPct', 'unique', 'uniqueSample'])
# Out:
#         dataFeatures dataType  null  nullPct  unique  \
# 0         customerID   object     0      0.0    7043
# 1             gender   object     0      0.0       2
# 2      SeniorCitizen    int64     0      0.0       2
# 3            Partner   object     0      0.0       2
# 4         Dependents   object     0      0.0       2
# 5             tenure    int64     0      0.0      73
# 6       PhoneService   object     0      0.0       2
# 7      MultipleLines   object     0      0.0       3
# 8    InternetService   object     0      0.0       3
# 9     OnlineSecurity   object     0      0.0       3
# 10      OnlineBackup   object     0      0.0       3
# 11  DeviceProtection   object     0      0.0       3
# 12       TechSupport   object     0      0.0       3
# 13       StreamingTV   object     0      0.0       3
# 14   StreamingMovies   object     0      0.0       3
# 15          Contract   object     0      0.0       3
# 16  PaperlessBilling   object     0      0.0       2
# ...

# %% [markdown]
# We have no missing value, but as we can see the column TotalCharges have an object data type but when we sampled it they had some numerical value. Let's try to convert this column data type to float

# %% [markdown]
# It seems there is some string data that could not be converted to float, Let's try to find the row that is problematic

# %%
# this cell is error checking when I want to convert TotalCharges column data type to float

# total_charges = pd.to_numeric(df['TotalCharges'], downcast='float')
# total_charges

# %%
index_error = []
index_success = []

for i in range(len(df['TotalCharges'])):
    try:
        pd.to_numeric(df['TotalCharges'][i])
        index_success.append(i)
    except:
        index_error.append(i)
df.loc[index_error]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %% [markdown]
# There are 11 datas with string space character at the TotalCharges Column

# %% [markdown]
# ## Question 1
# In your opinion, Why this datas filled with empty String? Is it related with another column?

# %%
df_err = df.loc[index_error]
df_err
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %% [markdown]
# Menjawab Quetion 1;
# - Jika dilihat sekilas dari dataframe diatas terlihat beberapa kolom juga memperlihatkan pola value yang cukup menarik saat TotalCharge-nya berisi empty string.
# - Kolom/Fitur SeniorCitizen, tenure berisi angka nol.
# - Kolom Partner lebih banyak yang berisi value 'No'.
# - Kolom Dependen berisi value 'Yes', sedangkan kolom churn berisi value 'No'.
# - Kolom Contract lebih banyak yang berisi value 'Two Year'.
# - Kolom PaymentMethod lebih banyak yang berisi value 'Mailed Checked'.
# - Kolom PaperlessBilling lebih banyak yang berisi value 'No'.
# - Dugaan sementara kolom TotalCharge yang berisi empty string kemungkinan dipengaruhi kolom SeniorCitzen, tenure, Partner, Dependen, Contract, PaymentMethod, PaperlessBilling.
# - Namun untuk lebih jelas lagi akan di check menggunakan uji korelasi Pearson dan Spermann untuk sesama kolom yang mempunyai data sama - sama numerical atau di cek korelasinya dengan kolom yang mempunyai data type categorical atau object setelah mengisi kolom TotalCharges yang kosong dengan 0 dan merubah tipe data kolom tersebut menjadi float

# %% [markdown]
# Try to replace this string value with 0 and convert the Total Charges to the float data type now

# %%
for i in range(len(df['TotalCharges'])):
    try:
        pd.to_numeric(df['TotalCharges'][i], downcast='float')
    except:
        df['TotalCharges'][i] = 0
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# Check once more the data row that was previously have string value to make sure the data have been replaced by 0

# %%
df['TotalCharges'] =  pd.to_numeric(df['TotalCharges'], downcast='float')
df.loc[index_error]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.732178
# std         0.368612    24.559481       30.090047   2266.794434
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.549988
# 50%         0.000000    29.000000       70.350000   1394.550049
# 75%         0.000000    55.000000       89.850000   3786.599976
# max         1.000000    72.000000      118.750000   8684.799805

# %%
plt.subplots(figsize=(8,8))
sns.heatmap(df.corr(), annot=True, linewidth=1)

# %%
plt.subplots(figsize=(8,8))
sns.heatmap(df.corr('spearman'), annot=True, linewidth=1)

# %%
def correlation_ratio(categories, measurements):
    fcat, _ = pd.factorize(categories)
    cat_num = np.max(fcat)+1
    y_avg_array = np.zeros(cat_num)
    n_array = np.zeros(cat_num)
    for i in range(0,cat_num):
        cat_measures = measurements[np.argwhere(fcat == i).flatten()]
        n_array[i] = len(cat_measures)
        y_avg_array[i] = np.average(cat_measures)
    y_total_avg = np.sum(np.multiply(y_avg_array,n_array))/np.sum(n_array)
    numerator = np.sum(np.multiply(n_array,np.power(np.subtract(y_avg_array,y_total_avg),2)))
    denominator = np.sum(np.power(np.subtract(measurements,y_total_avg),2))
    if numerator == 0:
        eta = 0.0
    else:
        eta = np.sqrt(numerator/denominator)
    return eta

def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x,y)
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2/n
    r,k = confusion_matrix.shape
    phi2corr = max(0, phi2-((k-1)*(r-1))/(n-1))
    rcorr = r-((r-1)**2)/(n-1)
    kcorr = k-((k-1)**2)/(n-1)
    return np.sqrt(phi2corr/min((kcorr-1),(rcorr-1)))

# %%
categorical_columns = df.select_dtypes('object').columns

# %%
import scipy.stats as ss
cramers = []
for i in categorical_columns:
    cramers.append(cramers_v(df['TotalCharges'], df[i]))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in double_scalars

# %%
res = pd.DataFrame(data = [categorical_columns, cramers]).T 
res.columns = ['Column', 'Cramers_V']
res.sort_values(by = 'Cramers_V', ascending = False)
# Out:
#               Column  Cramers_V
# 13          Contract   0.209506
# 10       TechSupport   0.182285
# 12   StreamingMovies   0.180279
# 11       StreamingTV   0.180138
# 9   DeviceProtection   0.177654
# 7     OnlineSecurity    0.17673
# 6    InternetService   0.174687
# 8       OnlineBackup   0.173682
# 5      MultipleLines   0.173462
# 4       PhoneService   0.144113
# 2            Partner   0.138133
# 15     PaymentMethod   0.110696
# 3         Dependents   0.110126
# 1             gender  0.0719996
# 14  PaperlessBilling  0.0664928
# 16             Churn          0
# 0         customerID        NaN

# %% [markdown]
# Lanjutan menjawab Question 1;
# - Uji korelasi diatas dilakukan dengan menggunakan  seluruh data pada dataframe.
# - Hasil uji korelasi kolom TotalCharges dengan semua kolom numerical menunjukkan korelasi yang cukup kuat dengan kolom tenure dan korelasi kuat keduanya dengan kolom MonthlyCharges. Sedangkan korelasi dengan kolom SeniorCitizen tidak terlalu kuat.
# - Untuk hasil uji korelasi kolom TotalCharges dengan kolom categorical, nilai Cramers_V dari yang tertinggi ke yang paling rendah adalah dengan kolom Contract, TechSupport, StreamingTV, dll.
# - Jika digabungkan dengan dugaan awal diatas, maka dapat disimpulkan kolom TotalCharge memiliki korelasi yang kuat dengan kolom tenure dan contract.
# - Namun dapat dikatakan juga beberpa kolom lain seperti SeniorCitizen, Partner, Dependen, PaymentMethod, PaperlessBilling kemungkinan besar yang mempengaruhi beberapa kolom di TotalCharge berisi empty string.

# %% [markdown]
# I find it interesting that some people still pay their bill via mailed check, lets try to filter the dataset to only get the data with Mailed check class from the PaymentMethod feature

# %%
df[df['PaymentMethod'] == 'Mailed check']
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 7     6713-OKOMC  Female              0      No         No      10
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 16    8191-XWSZG  Female              0      No         No      52
# ...          ...     ...            ...     ...        ...     ...
# 7019  9710-NJERN  Female              0      No         No      39
# 7027  0550-DCXLH    Male              0      No         No      13
# 7030  0871-OPBXW  Female              0      No         No       2
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1             Yes                No             DSL                  Yes  ...
# ...

# %% [markdown]
# I am kinda curious, is there any difference between people who have partner or not for people who choose mailed check. Let's try to visualize this by using the countplot. I would also like to create a grid with the Payment Method as the columns to see the difference between each payment method.

# %%
sns.countplot(df[df['PaymentMethod'] == 'Mailed check']['Partner'])
plt.title('Mailed check Payment Method by Partner')
plt.show()

# %%
# for i in ['Electronic check', 'Mailed check', 'Bank transfer (automatic)', 'Credit card (automatic)']:
#     sns.countplot(df[df['PaymentMethod'] == i]['Partner'])
#     plt.title('PaymentMethod = {}'.format(i))
#     plt.show()

# %%
g = sns.FacetGrid(df, col="PaymentMethod", col_order=["Electronic check", "Mailed check", "Bank transfer (automatic)", "Credit card (automatic)"])
g = g.map(plt.hist, "Partner")
g

# %% [markdown]
# Seems there is interesting finding that people who paid via Mailed Check are less likely to have partner compared to the other payment method. Let's try to use another feature to find any interesting finding, this time I would use the tenure feature with distribution plot. Just like before, I would create grid with different payment method as the columns.

# %%
plt.figure(figsize=(6,6))
sns.distplot(df[df['PaymentMethod'] == 'Mailed check']['tenure'])
plt.title('Tenure distribution with Mailed Check Payment Method')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
for i in ['Electronic check', 'Mailed check', 'Bank transfer (automatic)', 'Credit card (automatic)']:
    sns.distplot(df[df['PaymentMethod'] == i]['tenure'])
    plt.title('PaymentMethod = {}'.format(i))
    plt.show()

# %%
g = sns.FacetGrid(df, col="PaymentMethod", col_order=["Electronic check", "Mailed check", "Bank transfer (automatic)", "Credit card (automatic)"])
g = g.map(sns.distplot, "tenure")
g

# %% [markdown]
# ## Question 2
#
# From the plot above, what could you conclude about people who paid via mailed check? Also. is there any relationship between the tenure and partner column with the payment method?

# %% [markdown]
# Menjawab Question 2;
# - Dari plot diatas dapat dilihat untuk PaymentMethod dengan Mailed check lebih banyak customer yang tidak termasuk kedalam partner dan hanya mempunyai tenure lebih banyak di kurang dari 25 atau bahkan cenderung banyak yang 0.
# - Berdasarkan plot dapat dikatakan jika antara kolom tenure dan Partner dengan kolom PaymentMethod memiliki suatu hubungan.

# %% [markdown]
# That is enough EDA between feature, now let's focus to the our target (Churn). First, try to visualize the count of the Churn feature

# %%
sns.countplot(df['Churn'])
plt.show()

# %% [markdown]
# It seems we have a case of imbalanced dataset for churn prediction. Let's try to visualize the distirbution for every category and numerical columns that we have. Before we proceed, replace the SeniorCitizen feature value with 0 as No and 1 as Yes.
#
# *Note: if you use looping for showing all the plot, don't forget to add plt.show() after each iteration*

# %%
# sns.countplot(x="gender", hue="Churn", data=df)
# plt.show()

# %%
for i in categorical_columns:
    if (i != 'customerID') and (i != 'Churn'): 
        sns.countplot(x=i, hue="Churn", data=df)
        plt.show()

# %%
# categorical_columns = df.select_dtypes('object').columns
numerical_columns = df.select_dtypes(include=np.number).columns.tolist()
# numerical_columns
# Out:
# ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges']

# %%
churn_yes = df[df['Churn'] == 'Yes']
churn_no = df[df['Churn'] == 'No']

for i in numerical_columns:
    if (i != 'SeniorCitizen'): 
        sns.distplot(churn_yes[i], kde_kws={"label" : "Churn"})
        sns.distplot(churn_no[i], kde_kws={"label" : "Not Churn"})
        plt.show()

# %% [markdown]
# ## Question 3
#
# Is there any interesting insight that you could find from the plot above?

# %% [markdown]
# Dilihat dari countplot dan distplot diatas, maka ada beberapa hal menarik yang diantaranya:
# - Pada kolom Dependents, baik customer yang churn maupun tidak, jumlah terbanyak beradapa kategori Dependents 'No' yang jauh signifikan melebihi kategori Dependents 'Yes'.
# - Kebalikannya dengan kolom PhoneService, baik customer yang churn maupun tidak, jumlah terbanyak beradapa kategori PhoneService 'Yes' yang jauh signifikan melebihi kategori PhoneService 'No'.
# - Pada kolom MultipleLines, baik customer yang churn maupun tidak, kategori MultipleLines 'Yes' dan MultipleLines 'No' memiliki jumlah yang lebih banyak jika dibanding dengan kategori MultipleLines 'No Phone Service'.
# - Pada kolom InternetService, jumlah churn maupun yang tidak hampir berimbang untuk kategori InternetService 'Fiber optic'. Lain halnya dengan kategori InternetService 'Yes' ataupun yang 'No' yang memiliki gap jumlah antara customer yang churn ataupun tidak cukup jauh.
# - Pada kolom Online Security juga serupa dengan kolom InternetService, yaitu kategori Online Security 'No' yang memiliki jumlah antara customer yang churn dan tidak hampir berimbang. Namun untuk kategori yang 'Yes' dan 'No Internet Service' mempunyai gap jumlah customer yang churn dan tidak cukup besar.
# - Pada kolom Online Backup, hanya kategori 'No Internet Service' yang memiliki jumlah gap cukup besar dibanding kategori 'Yes' dan 'No'.
# - Serupa dengan kolom Online Backup, pada kolom DeviceProtection, TechSupport, StreamingTV, StreamingMovies yang juga memiliki jumlah gap cukup besar pada kategori 'No Internet Service' jika dibanding kategori 'Yes' dan 'No'.
# - Pada kolom contract, hanya kategori 'Two Year' yang memiliki gap paling besar antara customer churn dan tidak jika dibanding dengan kategori yang 'Yes' maupun 'No'.
# - Pada kategori PaperlessBilling, kategori 'No' memiliki jumlah gap paling besar jika dibanding dengan kategori yang 'Yes'.
# - Pada kategori PaymentMethod, hanya kategori 'Electronic check' yang memiliki jumlah berimbang untuk jumlah gap antara customer churn maupun tidak jika dibanding dengan 3 kategori yang lainnya.
# - Pada kolom tenure dan TotalCharges, jumlah customer yang churn paling banyak berada pada nilai tenure dan TotalCharges nol.
# - Pada kolom MonthlyCharge, jumlah churn paling banyak berada disekitar 65-105. Namun untuk customer yang tidak churn berada pada nilai MonthlyCharge yang mendekati nol.

# %% [markdown]
# As our aim is to use machine learning for prediction, lets prepare our columns to be ready for machine learning activities. First, drop the CustomerID column then change all the category columns into numerical value by using get_dummies (OneHotEncoder) except the target column (Churn). Also, set the drop_first parameter as True.
#
# At the same time, change the Churn feature value with No as 0 and Yes as 1

# %%
df_new = df.drop(['customerID'], axis=1)

# %%
df_new['Churn'] = df['Churn'].apply(lambda x: 1 if x == 'Yes' else 0)
df_new['SeniorCitizen'] = df['SeniorCitizen'].apply(lambda x: 'Yes' if x == 1 else 'No')

# %%
df_new = pd.get_dummies(data = df_new, drop_first = True, columns = ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod'])

# %%
df_churn = df_new['Churn']
df_new2 = df_new.drop(['Churn'], axis=1)

# %%
df_new2.head()
# Out:
#    tenure  MonthlyCharges  TotalCharges  gender_Male  SeniorCitizen_Yes  \
# 0       1           29.85     29.850000            0                  0
# 1      34           56.95   1889.500000            1                  0
# 2       2           53.85    108.150002            1                  0
# 3      45           42.30   1840.750000            1                  0
# 4       2           70.70    151.649994            0                  0
#
#    Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 0            1               0                 0
# 1            0               0                 1
# 2            0               0                 1
# 3            0               0                 0
# 4            0               0                 1
#
#    MultipleLines_No phone service  MultipleLines_Yes  ...  \
# 0                               1                  0  ...
# 1                               0                  0  ...
# ...

# %%
df_new2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 30 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   tenure                                 7043 non-null   int64
#  1   MonthlyCharges                         7043 non-null   float64
#  2   TotalCharges                           7043 non-null   float32
#  3   gender_Male                            7043 non-null   uint8
#  4   SeniorCitizen_Yes                      7043 non-null   uint8
#  5   Partner_Yes                            7043 non-null   uint8
#  6   Dependents_Yes                         7043 non-null   uint8
#  7   PhoneService_Yes                       7043 non-null   uint8
#  8   MultipleLines_No phone service         7043 non-null   uint8
#  9   MultipleLines_Yes                      7043 non-null   uint8
# ...

# %% [markdown]
# ## Unsurpervised Modelling

# %% [markdown]
# Before we do any of the supervised modelling, let's do some data mining from our data. Remember, as lot of unsupervised model based on distance means that we need to rescale our data to have a same scale.
#
# In our case, we would use all the data except the target data for data mining.
#
# First, use the boxplot to check all the data distribution

# %%
# df_new2.columns

# %%
plt.subplots(figsize=(7,7))
sns.boxplot(data=df_new2)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Just from the boxplot, we could see that the scale is not similar. In this case, lets rescale all the data by using the StandardScaler then check the data one more time to know our data distribution

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(df_new2)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_features = scaler.transform(df_new2)

# %%
df_new3 = pd.DataFrame(scaled_features,columns=df_new2.columns)
# df_new3.head()
# Out:
#      tenure  MonthlyCharges  TotalCharges  gender_Male  SeniorCitizen_Yes  \
# 0 -1.277445       -1.160323     -0.992611    -1.009559          -0.439916
# 1  0.066327       -0.259629     -0.172165     0.990532          -0.439916
# 2 -1.236724       -0.362660     -0.958066     0.990532          -0.439916
# 3  0.514251       -0.746535     -0.193672     0.990532          -0.439916
# 4 -1.236724        0.197365     -0.938874    -1.009559          -0.439916
#
#    Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 0     1.034530       -0.654012         -3.054010
# 1    -0.966622       -0.654012          0.327438
# 2    -0.966622       -0.654012          0.327438
# 3    -0.966622       -0.654012         -3.054010
# 4    -0.966622       -0.654012          0.327438
#
#    MultipleLines_No phone service  MultipleLines_Yes  ...  \
# 0                        3.054010          -0.854176  ...
# 1                       -0.327438          -0.854176  ...
# ...

# %%
plt.subplots(figsize=(8,8))
sns.boxplot(data=df_new3)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# We have lot of feature to be put into our unsupervised model, because of that let's use PCA to reduce our feature to 2 feature with random_state = 101. PC1 and PC2.

# %%
len(df_new3.columns)
# Out:
# 30

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2, random_state=101)

# %%
pca.fit(df_new3)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=101,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
x_pca = pca.transform(df_new3)

# %%
df_new4 = pd.DataFrame(x_pca, columns=[f'PC{i}' for i in range (1,3)])
df_new4
# Out:
#            PC1       PC2
# 0    -0.432402 -3.150994
# 1    -0.204024 -0.794405
# 2    -0.160382 -2.089736
# 3    -0.898671 -0.878803
# 4    -0.613839 -3.175062
# ...        ...       ...
# 7038 -1.895955  1.301241
# 7039 -3.132402  3.147387
# 7040 -0.342003 -2.486628
# 7041 -0.616559 -2.049118
# 7042 -3.009192  2.249887
#
# [7043 rows x 2 columns]

# %%
pca.explained_variance_ratio_
# Out:
# array([0.33179753, 0.11983851])

# %%
pca.components_
# Out:
# array([[-0.07156063, -0.28244848, -0.18490261,  0.00354973, -0.07216722,
#         -0.02533954,  0.04126051,  0.03010365, -0.03010365, -0.11094488,
#         -0.17950749,  0.30231423,  0.30231423, -0.12178473,  0.30231423,
#         -0.15317882,  0.30231423, -0.1595262 ,  0.30231423, -0.12945962,
#          0.30231423, -0.17904664,  0.30231423, -0.18003832, -0.00232007,
#          0.03710113, -0.11956739, -0.01393225, -0.09410831,  0.13244787],
#        [ 0.43796001,  0.08347014,  0.37646375, -0.00218697, -0.05961108,
#          0.26146808,  0.1858362 ,  0.11598964, -0.11598964,  0.18453889,
#         -0.04047233,  0.11740363,  0.11740363,  0.1734452 ,  0.11740363,
#          0.16879155,  0.11740363,  0.1939854 ,  0.11740363,  0.19192813,
#          0.11740363,  0.14252935,  0.11740363,  0.14283926,  0.09566753,
#          0.35277698, -0.06470546,  0.18338274, -0.21402549, -0.05449559]])

# %% [markdown]
# Our 2 PC only explained around 45 variance of the data, but we could just work with this data right now. Let's use the scatter plot to see the distribution of the 2 PC with the Churn feature as the hue

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=df_churn)
plt.xlabel('PC1')
plt.ylabel('PC2')
# plt.legend()
# Out:
# Text(0, 0.5, 'PC2')

# %% [markdown]
# Seems our 2 PC resulting in the 2 different group, it is really interesting as it is not usable for separating our Churn feature but it might end up with another fascinating observation.
#
# Now, we would use KMeans, DBSCAN, and HDBSCAN to cluster our 2 PC. This time, I already done some analysis and find the best parameter we could use. Try to use the KMeans model with n_cluster = 2, DBSCAN model with eps = 0.4 and min_samples = 2, and HDBSCAN model with min_cluster_size =2 and min_samples = 25
#
# Then create the scatter plot to compare the separation performance of each model.

# %%
# df_new4['Churn'] = df_churn
df_new4
# Out:
#            PC1       PC2
# 0    -0.432402 -3.150994
# 1    -0.204024 -0.794405
# 2    -0.160382 -2.089736
# 3    -0.898671 -0.878803
# 4    -0.613839 -3.175062
# ...        ...       ...
# 7038 -1.895955  1.301241
# 7039 -3.132402  3.147387
# 7040 -0.342003 -2.486628
# 7041 -0.616559 -2.049118
# 7042 -3.009192  2.249887
#
# [7043 rows x 2 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from hdbscan import HDBSCAN

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(df_new4)
dfKmeans = pd.DataFrame(df_new4)
dfKmeans['Category'] = kmeans.labels_

# %%
dbscan = DBSCAN(eps=0.4, min_samples = 2).fit(df_new4)
dfDBSCAN = df_new4.copy()
dfDBSCAN['Category'] = dbscan.labels_

# %%
hdbscan = HDBSCAN(min_cluster_size=2, min_samples = 25)
hdbscan.fit(df_new4)
dfHDBSCAN = df_new4.copy()
dfHDBSCAN['Category'] = hdbscan.labels_

# %%
centroids = kmeans.cluster_centers_
f, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, sharey=True,figsize=(16,8))

ax1.set_title("Original")
ax1.scatter(df_new4['PC1'], df_new4['PC2'], c =df_new4['Category'], cmap = 'rainbow')

ax2.set_title('K Means')
ax2.scatter(dfKmeans['PC1'], dfKmeans['PC2'], c =dfKmeans['Category'], cmap = 'rainbow')
ax2.scatter(centroids[:, 0], centroids[:, 1], marker='*', c='b', s=250)

core = dbscan.components_
ax3.set_title('DBSCAN')
ax3.scatter(dfDBSCAN['PC1'], dfDBSCAN['PC2'], c =dfDBSCAN['Category'], cmap = 'rainbow')
ax3.scatter(core[:, 0], core[:, 1], marker='o', c='black', s=5)

ax4.set_title('HDBSCAN')
ax4.scatter(dfHDBSCAN['PC1'], dfHDBSCAN['PC2'], c =dfHDBSCAN['Category'], cmap = 'rainbow')

# %% [markdown]
# Seems all of our our model resulting in 2 different cluster, just like we expected. Now, return the label from the KMeans model back to the original data and use the pair plot to see the relation between the numerical value with the label as the hue (I am personally name it k-label)

# %%
df_new2
# Out:
#       tenure  MonthlyCharges  TotalCharges  gender_Male  SeniorCitizen_Yes  \
# 0          1           29.85     29.850000            0                  0
# 1         34           56.95   1889.500000            1                  0
# 2          2           53.85    108.150002            1                  0
# 3         45           42.30   1840.750000            1                  0
# 4          2           70.70    151.649994            0                  0
# ...      ...             ...           ...          ...                ...
# 7038      24           84.80   1990.500000            1                  0
# 7039      72          103.20   7362.899902            0                  0
# 7040      11           29.60    346.450012            0                  0
# 7041       4           74.40    306.600006            1                  1
# 7042      66          105.65   6844.500000            1                  0
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# ...

# %%
df_new5 = df_new2[['tenure', 'MonthlyCharges', 'TotalCharges']]
df_new5['Churn'] = df_churn
df_new5['k-label'] = kmeans.labels_
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_new5
# Out:
#       tenure  MonthlyCharges  TotalCharges  Churn  k-label
# 0          1           29.85     29.850000      0        0
# 1         34           56.95   1889.500000      0        0
# 2          2           53.85    108.150002      1        0
# 3         45           42.30   1840.750000      0        0
# 4          2           70.70    151.649994      1        0
# ...      ...             ...           ...    ...      ...
# 7038      24           84.80   1990.500000      0        0
# 7039      72          103.20   7362.899902      0        0
# 7040      11           29.60    346.450012      0        0
# 7041       4           74.40    306.600006      1        0
# 7042      66          105.65   6844.500000      0        0
#
# [7043 rows x 5 columns]

# %% [markdown]
# ### Saya kurang tau permasalahannya, tapi malah keluar error seperti dibawah yang seharusnya bisa keluar sama seperti yang dicontohkan untuk pairplotnya
# #### RuntimeError: Selected KDE bandwidth is 0. Cannot estimate density.

# %%
# sns.pairplot(df_new5[['tenure', 'MonthlyCharges', 'TotalCharges', 'Churn', 'k-label']], hue='k-label')

# %% [markdown]
# ## Question 4
# Just strictly from the plot above, What kind of insight you could find there?

# %% [markdown]
# Menjawab Question 4;
# - Hasil klasterisasi berdasarkan k-means terbagi menjadi 2 cluster.
# - Untuk Churn dan tenure tidak terlalu ada perbedaan yang signifikan terhadap pembagian cluster
# - Cluster 0 : nilai TotalCharges berkisar 0-9000, MonthlyCharge berkisar 0-120.
# - Cluster 1 : nilai TotalCharges berkisar 0-2000, MonthlyCharge berkisar 20-30.

# %%
df_new3
# Out:
#         tenure  MonthlyCharges  TotalCharges  gender_Male  SeniorCitizen_Yes  \
# 0    -1.277445       -1.160323     -0.992611    -1.009559          -0.439916
# 1     0.066327       -0.259629     -0.172165     0.990532          -0.439916
# 2    -1.236724       -0.362660     -0.958066     0.990532          -0.439916
# 3     0.514251       -0.746535     -0.193672     0.990532          -0.439916
# 4    -1.236724        0.197365     -0.938874    -1.009559          -0.439916
# ...        ...             ...           ...          ...                ...
# 7038 -0.340876        0.665992     -0.127605     0.990532          -0.439916
# 7039  1.613701        1.277533      2.242606    -1.009559          -0.439916
# 7040 -0.870241       -1.168632     -0.852932    -1.009559          -0.439916
# 7041 -1.155283        0.320338     -0.870513     0.990532           2.273159
# 7042  1.369379        1.358961      2.013897     0.990532          -0.439916
#
# ...

# %% [markdown]
# ### Supervised Modelling

# %% [markdown]
# First, done the Train Test Split by using random_state=101 and test size =0.2

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df_new3,df_churn, test_size=0.20, random_state=101)

# %% [markdown]
# If you remember, we have a case of data imbalance for our Churn feature. We could use SMOTE to try oversampling our data. In this time try use SMOTE to our x_train data but keep it in new variable so we would have 2 different kind of x_train; with and without oversampling.

# %%
y_train.value_counts()
# Out:
# 0    4148
# 1    1486
# Name: Churn, dtype: int64

# %%
y_test.value_counts()
# Out:
# 0    1026
# 1     383
# Name: Churn, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(sampling_strategy = 'minority')

oversampled_trainX, oversampled_trainY = sm.fit_sample(X_train, y_train)
oversampled_train = pd.concat([pd.DataFrame(oversampled_trainY), pd.DataFrame(oversampled_trainX)], axis = 1)

# %%
pd.Series(oversampled_trainY).value_counts()
# Out:
# 1    4148
# 0    4148
# Name: Churn, dtype: int64

# %%
print('The Normal X_train data')
# Out:
# The Normal X_train data

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5634 entries, 240 to 4959
# Data columns (total 30 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   tenure                                 5634 non-null   float64
#  1   MonthlyCharges                         5634 non-null   float64
#  2   TotalCharges                           5634 non-null   float64
#  3   gender_Male                            5634 non-null   float64
#  4   SeniorCitizen_Yes                      5634 non-null   float64
#  5   Partner_Yes                            5634 non-null   float64
#  6   Dependents_Yes                         5634 non-null   float64
#  7   PhoneService_Yes                       5634 non-null   float64
#  8   MultipleLines_No phone service         5634 non-null   float64
#  9   MultipleLines_Yes                      5634 non-null   float64
# ...

# %%
print('The oversampled X_train data')
# Out:
# The oversampled X_train data

# %%
oversampled_trainX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8296 entries, 0 to 8295
# Data columns (total 30 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   tenure                                 8296 non-null   float64
#  1   MonthlyCharges                         8296 non-null   float64
#  2   TotalCharges                           8296 non-null   float64
#  3   gender_Male                            8296 non-null   float64
#  4   SeniorCitizen_Yes                      8296 non-null   float64
#  5   Partner_Yes                            8296 non-null   float64
#  6   Dependents_Yes                         8296 non-null   float64
#  7   PhoneService_Yes                       8296 non-null   float64
#  8   MultipleLines_No phone service         8296 non-null   float64
#  9   MultipleLines_Yes                      8296 non-null   float64
# ...

# %% [markdown]
# ## Question 5
#
# This time, I would leave the supervised modelling for the Churn feature to be up to you. I would give some criteria that was necessary to get the maximum points. The criteria included:
#
# 1. Aim for one of the metric of your choice (either the performance metrics optimization such as increasing the Accuracy, or lowering the loss function such as Log Loss). Give me your reason why you choose these metric. Just aim for one metric, you do not need to try optimize everything.
#
# 2. Compare 3 supervise model of your choice. Try to optimize your metric for these 3 model by hyperparameter tuning and use it on both the oversampled data and normal one. Compare the model if there is a difference If you use the oversampled data or not. Then choose to work with the data that you think is the best. If you feel the model of your choice could not be optimized again, then choose the best model with the best hyperparameter. You do not need to really aim for the best model, but I want to see if you know the step of optimizing model and done hyperparameter tuning. We do not need to work on Feature Engineering for this time.
#
# 3. From your choice of model and data, use the Feature Importance method to see which feature that affecting the Churn feature. Explain what is your finding. There might be some randomness because of the method, but just try to explain from what the plot is showing.
#
# 4. Lastly, try to see if your model stable or not by using the K-Fold and CV method, as well as to try find the best training size by using the learning curve method. Use all your data again (the data you use for train test split).It does not matter if you model work is based on the oversampled data or not, just use the model base on the complete data (Once again, (the data you use for train test split).

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()
dtree_over = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
dtree_over.fit(oversampled_trainX, oversampled_trainY)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
predictions = dtree.predict(X_test)
predictions_over = dtree_over.predict(X_test)

predProb = dtree.predict_proba(X_test)
predProb_over = dtree_over.predict_proba(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.80      0.80      1026
#            1       0.45      0.44      0.45       383
#
#     accuracy                           0.70      1409
#    macro avg       0.62      0.62      0.62      1409
# weighted avg       0.70      0.70      0.70      1409

# %%
print(classification_report(y_test,predictions_over))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.79      0.80      1026
#            1       0.48      0.52      0.50       383
#
#     accuracy                           0.72      1409
#    macro avg       0.65      0.66      0.65      1409
# weighted avg       0.73      0.72      0.72      1409

# %% [markdown]
# Kesimpulan dari DecisionTree:
# - Jika melihat nilai accuracynya maka X_train, Y_train yang telah di oversample menggunakan SMOTE mampu menghasilkan nilai accuracy sebsar 0.72, sedangkan sebelum menggunakan SMOTE hanya memberikan nilai accuracy sebesar 0.70

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=100)
rfc_over = RandomForestClassifier(n_estimators=100)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rfc_over.fit(oversampled_trainX, oversampled_trainY)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rfc_pred = rfc.predict(X_test)
rfc_pred_over = rfc_over.predict(X_test)

# %%
print(classification_report(y_test,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.91      0.86      1026
#            1       0.64      0.42      0.51       383
#
#     accuracy                           0.78      1409
#    macro avg       0.73      0.67      0.68      1409
# weighted avg       0.76      0.78      0.76      1409

# %%
print(classification_report(y_test,rfc_pred_over))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84      1026
#            1       0.57      0.53      0.55       383
#
#     accuracy                           0.76      1409
#    macro avg       0.70      0.69      0.69      1409
# weighted avg       0.76      0.76      0.76      1409

# %% [markdown]
# Kesimpulan dari RandomForest:
# - Jika melihat nilai accuracynya maka X_train, Y_train yang telah di oversample menggunakan SMOTE hanya menghasilkan nilai accuracy sebsar 0.76, sedangkan sebelum menggunakan SMOTE hanya dapat memberikan nilai accuracy sebesar 0.78
# - Hal ini menunjukkan bahwa penggunaan RandomForest tidak cocok menggunakan data train yang telah di-oversample menggunakan SMOOTE.

# %% [markdown]
# ## K Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=1)
knn_over = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train,y_train)
knn_over.fit(oversampled_trainX, oversampled_trainY)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
pred = knn.predict(X_test)
pred_over = knn_over.predict(X_test)

# %%
print('WITH K = 1\n\n')
print(classification_report(y_test,pred))
# Out:
# WITH K = 1
#
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.80      1026
#            1       0.46      0.48      0.47       383
#
#     accuracy                           0.71      1409
#    macro avg       0.63      0.63      0.63      1409
# weighted avg       0.71      0.71      0.71      1409

# %%
print('WITH K = 1\n\n')
print(classification_report(y_test,pred_over))
# Out:
# WITH K = 1
#
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.76      0.78      1026
#            1       0.45      0.53      0.48       383
#
#     accuracy                           0.69      1409
#    macro avg       0.63      0.64      0.63      1409
# weighted avg       0.71      0.69      0.70      1409

# %%
knn2 = KNeighborsClassifier(n_neighbors=2)
knn2_over = KNeighborsClassifier(n_neighbors=2)

# %%
knn2.fit(X_train,y_train)
knn2_over.fit(oversampled_trainX, oversampled_trainY)

pred2 = knn2.predict(X_test)
pred2_over = knn2_over.predict(X_test)

# %%
print('WITH K = 2\n\n')
print(classification_report(y_test,pred2))
# Out:
# WITH K = 2
#
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84      1026
#            1       0.56      0.26      0.36       383
#
#     accuracy                           0.74      1409
#    macro avg       0.66      0.59      0.60      1409
# weighted avg       0.71      0.74      0.71      1409

# %%
print('WITH K = 2\n\n')
print(classification_report(y_test,pred2_over))
# Out:
# WITH K = 2
#
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.82      0.81      1026
#            1       0.47      0.44      0.46       383
#
#     accuracy                           0.71      1409
#    macro avg       0.63      0.63      0.63      1409
# weighted avg       0.71      0.71      0.71      1409

# %%
knn3 = KNeighborsClassifier(n_neighbors=3)
knn3_over = KNeighborsClassifier(n_neighbors=3)

# %%
knn3.fit(X_train,y_train)
knn3_over.fit(oversampled_trainX, oversampled_trainY)

pred3 = knn3.predict(X_test)
pred3_over = knn3_over.predict(X_test)

# %%
print('WITH K = 3\n\n')
print(classification_report(y_test,pred3))
# Out:
# WITH K = 3
#
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.82      1026
#            1       0.50      0.48      0.49       383
#
#     accuracy                           0.73      1409
#    macro avg       0.66      0.65      0.65      1409
# weighted avg       0.73      0.73      0.73      1409

# %%
print('WITH K = 3\n\n')
print(classification_report(y_test,pred3_over))
# Out:
# WITH K = 3
#
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.68      0.75      1026
#            1       0.44      0.66      0.52       383
#
#     accuracy                           0.67      1409
#    macro avg       0.64      0.67      0.64      1409
# weighted avg       0.73      0.67      0.69      1409

# %%
knn4 = KNeighborsClassifier(n_neighbors=4)
knn4_over = KNeighborsClassifier(n_neighbors=4)

# %%
knn4.fit(X_train,y_train)
knn4_over.fit(oversampled_trainX, oversampled_trainY)

pred4 = knn4.predict(X_test)
pred4_over = knn4_over.predict(X_test)

# %%
print('WITH K = 4\n\n')
print(classification_report(y_test,pred4))
# Out:
# WITH K = 4
#
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84      1026
#            1       0.56      0.34      0.42       383
#
#     accuracy                           0.75      1409
#    macro avg       0.67      0.62      0.63      1409
# weighted avg       0.72      0.75      0.73      1409

# %%
print('WITH K = 4\n\n')
print(classification_report(y_test,pred4_over))
# Out:
# WITH K = 4
#
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.74      0.78      1026
#            1       0.46      0.58      0.51       383
#
#     accuracy                           0.70      1409
#    macro avg       0.64      0.66      0.65      1409
# weighted avg       0.73      0.70      0.71      1409

# %% [markdown]
# Kesimpulan dari KNN:
# - Jika melihat nilai accuracynya dengan mencoba nilai n_neighbors=4, secara overall data train yang belum dilakukan oversampling menggunakan SMOTE mampu memberikan nilai accuracy yang lebih tinggi jika dibanding model yang menggunakan data train yang telah di oversampling.
# - Dugaan sementara, jika menggunakan data yang belum di oversampling tersebut dengan meningkatkan nilai n_neighbors sampai batas tertentu dapat meningkatkan nilai accuracy

# %% [markdown]
# Kesimpulan sementara dengan menggunakan DecisionTree, RandomForest, dan KNN;
# - Penggunaan model DecisionTree sangat bagus jika menggunakan data train yang telah di-oversampling menggunakan SMOTE.
# - Jika menggunakan data train originalnya maka lebih bagus jika menggunakan model RandomForest atau KNN, namun untuk KNN perlu menentukan n_neighbors yang tepat untuk mendapatkan nilai accuracy yang maksimum

# %% [markdown]
# ## RandomizedSearchCV
# Saya mencoba menemukan parameter terbaik dengan pada random forest dengan menggunakan RandomizedSearchCV. Saya lebih memilih randomforest dibanding KNN karena randomforest memiliki hyperparamter atau banyak parameter yang diperlukan untuk mencoba menemukan nilai accuracy terbaik. Sedangkan untuk KNN, pencarian nilai accuracy terbaik dapat dilakukan dengan mencoba - coba nilai dari n_neighbors

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop=2000, num=10)]

# Number of features to consider at every split
max_features = ['auto', 'sqrt']

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]

# Minimum number of samples required to split a node
min_samples_split = [int(x) for x in np.linspace(start = 100, stop = 1000, num = 100)]

# Minimum number of samples required at each leaf node
min_samples_leaf = [int(x) for x in np.linspace(1, 11, num = 10)]

# Method of selecting samples for training each tree
bootstrap = [True, False]

# %%
#Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# %%
rf_random = RandomizedSearchCV(estimator = rfc,
                              param_distributions = random_grid,
                              n_iter = 10, cv = 3, n_jobs = -1, scoring = 'accuracy')

# %%
rf_random_over = RandomizedSearchCV(estimator = rfc_over,
                              param_distributions = random_grid,
                              n_iter = 10, cv = 3, n_jobs = -1, scoring = 'accuracy')

# %%
rf_random.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=3, error_score=nan,
#                    estimator=RandomForestClassifier(bootstrap=True,
#                                                     ccp_alpha=0.0,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features='auto',
#                                                     max_leaf_nodes=None,
#                                                     max_samples=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_impurity_split=None,
#                                                     min_samples_leaf=1,
#                                                     min_samples_split=2,
# ...

# %%
rf_random_over.fit(oversampled_trainX, oversampled_trainY)
# Out:
# RandomizedSearchCV(cv=3, error_score=nan,
#                    estimator=RandomForestClassifier(bootstrap=True,
#                                                     ccp_alpha=0.0,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features='auto',
#                                                     max_leaf_nodes=None,
#                                                     max_samples=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_impurity_split=None,
#                                                     min_samples_leaf=1,
#                                                     min_samples_split=2,
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 200,
#  'min_samples_split': 327,
#  'min_samples_leaf': 3,
#  'max_features': 'auto',
#  'max_depth': 40,
#  'bootstrap': False}

# %%
rf_random_over.best_params_
# Out:
# {'n_estimators': 1600,
#  'min_samples_split': 209,
#  'min_samples_leaf': 2,
#  'max_features': 'sqrt',
#  'max_depth': 50,
#  'bootstrap': False}

# %% [markdown]
# Nilai Parameter terbaik dengan menggunakan RandomSearchCV untuk randomforest dengan data yang belum di oversampled adalah - -'n_estimators': 200,
#  'min_samples_split': 327,
#  'min_samples_leaf': 3,
#  'max_features': 'auto',
#  'max_depth': 40,
#  'bootstrap': False

# %% [markdown]
# ## Feature Importances - Permutation Importances

# %%
import warnings
warnings.filterwarnings("ignore")

from eli5 import show_weights
from eli5.sklearn import PermutationImportance

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

perm = PermutationImportance(rfc, scoring = 'accuracy', random_state=101).fit(X_test, y_test)
show_weights(perm, feature_names = list(X_test.columns))
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0165
#
#                     &plusmn; 0.0068
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 tenure
#             </td>
# ...

# %% [markdown]
# Kesimpulan dari Permutation Importances;
# - fitur yang cukup berperan dalam model randomforest ini jika diurutkan dari atas adalah tenure, InternetService_Fiber optic, Contract_One year, SeniorCitizen_Yes, dll.

# %% [markdown]
# ## Feature Importances - SHAP (SHapely Additive exPlanations)

# %%
import shap

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
X_test.iloc[1]
# Out:
# tenure                                  -1.277445
# MonthlyCharges                          -0.633533
# TotalCharges                            -0.985618
# gender_Male                              0.990532
# SeniorCitizen_Yes                       -0.439916
# Partner_Yes                             -0.966622
# Dependents_Yes                          -0.654012
# PhoneService_Yes                         0.327438
# MultipleLines_No phone service          -0.327438
# MultipleLines_Yes                       -0.854176
# InternetService_Fiber optic             -0.885660
# InternetService_No                      -0.525927
# OnlineSecurity_No internet service      -0.525927
# OnlineSecurity_Yes                      -0.633933
# OnlineBackup_No internet service        -0.525927
# OnlineBackup_Yes                        -0.725563
# DeviceProtection_No internet service    -0.525927
# DeviceProtection_Yes                    -0.723968
# TechSupport_No internet service         -0.525927
# ...

# %%
y_test.iloc[1]
# Out:
# 1

# %%
rfc.predict_proba(np.array(X_test.iloc[1]).reshape(1, -1))
# Out:
# array([[0.31, 0.69]])

# %%
explainer = shap.TreeExplainer(rfc)

# %%
shap_val = explainer.shap_values(X_test.iloc[1])

# %%
explainer.expected_value
# Out:
# array([0.73703408, 0.26296592])

# %%
shap_val
# Out:
# [array([-0.18386497, -0.014767  , -0.15701327,  0.00533281, -0.00853904,
#         -0.00554485,  0.00168643,  0.00798119,  0.00685563, -0.0025717 ,
#          0.07120462, -0.01223564, -0.00892356, -0.01797729, -0.01973549,
#         -0.01678305, -0.01078319,  0.00331565, -0.01795637, -0.01648038,
#         -0.01032756,  0.00608447, -0.01290183,  0.006364  , -0.00876526,
#         -0.0256414 , -0.04112161, -0.00430448,  0.03446007,  0.02591898]),
#  array([ 0.18386497,  0.014767  ,  0.15701327, -0.00533281,  0.00853904,
#          0.00554485, -0.00168643, -0.00798119, -0.00685563,  0.0025717 ,
#         -0.07120462,  0.01223564,  0.00892356,  0.01797729,  0.01973549,
#          0.01678305,  0.01078319, -0.00331565,  0.01795637,  0.01648038,
#          0.01032756, -0.00608447,  0.01290183, -0.006364  ,  0.00876526,
#          0.0256414 ,  0.04112161,  0.00430448, -0.03446007, -0.02591898])]

# %%
shap.initjs()
shap.force_plot(explainer.expected_value[1], shap_val[1], X_test.iloc[1])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";funct
# ...

# %% [markdown]
# Kesimpulan dari SHAP diatas jika menggunakan index 1 sebagai contoh;
# - tenure dan TotalCharge adalah dua fitur yang mampu memberikan kenaikan tertinggi dari nilai nilai probability outputnya.
# - sedangkan fitur utama yang menyebabkan penurunan nilai probability output yang cukup besar adalah InternetService_FiberOptic.

# %% [markdown]
# Kesimpulan dari penggunaan Fitur Importance baik Permutation maupun Shap;
# - Tenure dan InternetService_FiberOptic merupakan 2 fitur yang cukup berperan penting dalam model random forest ini.
# - Dimana tenure memiliki peran penting untuk peningkatan nilai output, sedangkan InternetService_FiberOptic memiiki peran penting dalam pengurangan nilai outputnya.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score,roc_auc_score, f1_score, log_loss, matthews_corrcoef

# %%
data = X_train
target = y_train

# %%
def calc_train_error(X_train, y_train, model):
    predictions = model.predict(X_train)
    predictProba = model.predict_proba(X_train)
    matt = matthews_corrcoef(y_train, predictions)
    f1 = f1_score(y_train, predictions, average ='macro')
    report = classification_report(y_train, predictions)
    roc_auc = roc_auc_score(y_train, predictProba[:, 1])
    accuracy = accuracy_score(y_train, predictions)
    confMatrix = confusion_matrix(y_train, predictions)
    logloss = log_loss(y_train,predictProba)
    return{
        'report' : report, 
        'matthew' : matt,
        'f1' : f1,
        'roc': roc_auc,
        'accuracy': accuracy,
        'confusion': confMatrix,
        'logloss' : logloss
    }

def calc_validation_error(X_test, y_test, model):
    predictions = model.predict(X_test)
    predictProba = model.predict_proba(X_test)
    matt = matthews_corrcoef(y_test, predictions)
    f1 = f1_score(y_test, predictions, average ='macro')
    report = classification_report(y_test, predictions)
    roc_auc = roc_auc_score(y_test, predictProba[:, 1])
    accuracy = accuracy_score(y_test, predictions)
    confMatrix = confusion_matrix(y_test, predictions)
    logloss = log_loss(y_test,predictProba)
    return{
        'report' : report, 
        'matthew' : matt,
        'f1' : f1,
        'roc': roc_auc,
        'accuracy': accuracy,
        'confusion': confMatrix,
        'logloss' : logloss
    }

def calc_metrics(X_train, y_train, X_test, y_test, model):
    model.fit(X_train, y_train)
    train_error = calc_train_error(X_train, y_train, model)
    validation_error = calc_validation_error(X_test, y_test, model)
    return train_error, validation_error

# %%
from sklearn.model_selection import KFold
K = 5
kf =KFold(n_splits = K, shuffle = True, random_state = 42)

# %%
train_errors = []
validation_errors = []
for train_index, val_index in kf.split(data, target):
    
    #split data
    X_train, X_val = data.iloc[train_index], data.iloc[val_index]
    y_train, y_val = target.iloc[train_index], target.iloc[val_index]
    
    #instantiate model
    logmodel = LogisticRegression()
    
    #calculate errors
    train_error, val_error = calc_metrics(X_train, y_train, X_val, y_val, logmodel)
    
    #append to appropiate list
    train_errors.append(train_error)
    validation_errors.append(val_error)

# %%
train_errors
# Out:
# [{'report': '              precision    recall  f1-score   support\n\n           0       0.85      0.90      0.87      3321\n           1       0.66      0.56      0.61      1186\n\n    accuracy                           0.81      4507\n   macro avg       0.76      0.73      0.74      4507\nweighted avg       0.80      0.81      0.80      4507\n',
#   'matthew': 0.4836783055291018,
#   'f1': 0.7397137935340783,
#   'roc': 0.8532542159785472,
#   'accuracy': 0.8087419569558465,
#   'confusion': array([[2983,  338],
#          [ 524,  662]], dtype=int64),
#   'logloss': 0.40688164816609124},
#  {'report': '              precision    recall  f1-score   support\n\n           0       0.85      0.90      0.88      3332\n           1       0.66      0.56      0.61      1175\n\n    accuracy                           0.81      4507\n   macro avg       0.76      0.73      0.74      4507\nweighted avg       0.80      0.81      0.81      4507\n',
#   'matthew': 0.4854906924429371,
# ...

# %%
for i, tr_err, val_err in zip(range(1,6,1), train_errors, validation_errors):
    print('Accuracy Train ke {} : {}'.format(i, tr_err['accuracy']))
    print('Accuracy Validation ke {} : {}'.format(i, val_err['accuracy']))
# Out:
# Accuracy Train ke 1 : 0.8087419569558465
# Accuracy Validation ke 1 : 0.80301685891748
# Accuracy Train ke 2 : 0.8107388506767251
# Accuracy Validation ke 2 : 0.805678793256433
# Accuracy Train ke 3 : 0.8080763257155535
# Accuracy Validation ke 3 : 0.80301685891748
# Accuracy Train ke 4 : 0.8047481695140892
# Accuracy Validation ke 4 : 0.8234250221827861
# Accuracy Train ke 5 : 0.8112244897959183
# Accuracy Validation ke 5 : 0.7930728241563055

# %%
for i, tr_err, val_err in zip(range(1,6,1), train_errors, validation_errors):
    print(f'Report Train ke {i} :')
    print(tr_err['report'])
    print(f'Report Validation ke {i} :')
    print(val_err['report'])
# Out:
# Report Train ke 1 :
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.87      3321
#            1       0.66      0.56      0.61      1186
#
#     accuracy                           0.81      4507
#    macro avg       0.76      0.73      0.74      4507
# weighted avg       0.80      0.81      0.80      4507
#
# Report Validation ke 1 :
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.87       827
#            1       0.64      0.58      0.61       300
#
#     accuracy                           0.80      1127
#    macro avg       0.75      0.73      0.74      1127
# weighted avg       0.80      0.80      0.80      1127
#
# Report Train ke 2 :
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.88      3332
#            1       0.66      0.56      0.61      1175
#
#     accuracy                           0.81      4507
# ...

# %% [markdown]
# Kesimpulan dari K-Fold:
# - Dengan menggunakan K=5, nilai accuracy jika baik dari report train 1-5 dan report validation 1-5 adalah berkisar diantara 79-82.
# - Dari hasil nilai accuracy diatas menunjukkan data cukup stabil karena nilai accuracy berkisar diantara 79-82
